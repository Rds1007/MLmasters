# %%
import requests
import pandas as pd
from pandas.io.json import json_normalize
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()

# %%
len(data)
# Out:
# 30

# %%
data_flat = {}

# %%
def flatten_dict(obj,name=''):
    
    for k,v in obj.items():
                        if((type(v) is str) or (type(v) is int) or (type(v) is bool) or (isinstance(v, type(None)))):
                            if(isinstance(v, type(None))):
                                key_val = name + '_'+ str(k)
                                data_flat[key_val]=None
                            else:
                                key_val = name + '_' + str(k)
                                data_flat[key_val]=v
                        elif(type(v) is dict):
                            name =str(k)
                            flatten_dict(v,name)
                            name = ''
                        elif(type(v) is list):
                            for i in range(len(v)):
                                name=str(k) +'_'+ str(float(i))
                                flatten_dict(v[i],name)
                                name=''
                        else:
                            name = ''
    return data_flat

# %%
listing = []

# %%
for i in range(len(data)):
    data_local = flatten_dict(data[i])
    listing.append(data_local)

# %%
listing
# Out:
# [{'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
# ...
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'},
#  {'_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209',
#   '_repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   '_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/labels{/name}',
#   '_comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/comments',
#   '_events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/36209/events',
#   '_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   '_id': 695498559,
#   '_node_id': 'MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5',
#   '_number': 36209,
#   '_title': 'REF: share more EA methods',
#   'user_login': 'jbrockmendel',
#   'user_id': 8078968,
#   'user_node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#   'user_avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#   'user_gravatar_id': '',
#   'user_url': 'https://api.github.com/users/jbrockmendel',
#   'user_html_url': 'https://github.com/jbrockmendel',
#   'user_followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#   'user_following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#   'user_gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#   'user_starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#   'user_subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#   'user_organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#   'user_repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#   'user_events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#   'user_received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#   'user_type': 'User',
#   'user_site_admin': False,
#   '_state': 'open',
#   '_locked': False,
#   '_assignee': None,
#   '_milestone': None,
#   '_comments': 0,
#   '_created_at': '2020-09-08T02:37:54Z',
#   '_updated_at': '2020-09-09T17:49:14Z',
#   '_closed_at': None,
#   '_author_association': 'MEMBER',
#   '_active_lock_reason': None,
#   'pull_request_url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/36209',
#   'pull_request_html_url': 'https://github.com/pandas-dev/pandas/pull/36209',
#   'pull_request_diff_url': 'https://github.com/pandas-dev/pandas/pull/36209.diff',
#   'pull_request_patch_url': 'https://github.com/pandas-dev/pandas/pull/36209.patch',
#   '_body': '',
#   '_performed_via_github_app': None,
#   'labels_0.0_id': 127681,
#   'labels_0.0_node_id': 'MDU6TGFiZWwxMjc2ODE=',
#   'labels_0.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Refactor',
#   'labels_0.0_name': 'Refactor',
#   'labels_0.0_color': 'FCE94F',
#   'labels_0.0_default': False,
#   'labels_0.0_description': 'Internal refactoring of code',
#   'labels_1.0_id': 35818298,
#   'labels_1.0_node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#   'labels_1.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#   'labels_1.0_name': 'API Design',
#   'labels_1.0_color': 'AD7FA8',
#   'labels_1.0_default': False,
#   'labels_1.0_description': None,
#   'labels_2.0_id': 87485152,
#   'labels_2.0_node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#   'labels_2.0_url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#   'labels_2.0_name': 'Deprecate',
#   'labels_2.0_color': '5319e7',
#   'labels_2.0_default': False,
#   'labels_2.0_description': 'Functionality to remove in pandas',
#   'milestone_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73',
#   'milestone_html_url': 'https://github.com/pandas-dev/pandas/milestone/73',
#   'milestone_labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/73/labels',
#   'milestone_id': 5479819,
#   'milestone_node_id': 'MDk6TWlsZXN0b25lNTQ3OTgxOQ==',
#   'milestone_number': 73,
#   'milestone_title': '1.2',
#   'milestone_description': '',
#   'creator_login': 'jreback',
#   'creator_id': 953992,
#   'creator_node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#   'creator_avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#   'creator_gravatar_id': '',
#   'creator_url': 'https://api.github.com/users/jreback',
#   'creator_html_url': 'https://github.com/jreback',
#   'creator_followers_url': 'https://api.github.com/users/jreback/followers',
#   'creator_following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#   'creator_gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#   'creator_starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#   'creator_subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#   'creator_organizations_url': 'https://api.github.com/users/jreback/orgs',
#   'creator_repos_url': 'https://api.github.com/users/jreback/repos',
#   'creator_events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#   'creator_received_events_url': 'https://api.github.com/users/jreback/received_events',
#   'creator_type': 'User',
#   'creator_site_admin': False,
#   '_open_issues': 55,
#   '_closed_issues': 333,
#   '_due_on': '2020-11-29T08:00:00Z'}]
